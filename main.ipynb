# %%
# define rooms and items

couch = {
    "name": "couch",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

piano = {
    "name": "piano",
    "type": "furniture",
}

game_room = {
    "name": "game room",
    "type": "room",
}

queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}

door_b = {
    "name": "door b",
    "type": "door",
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

door_c = {
    "name": "door c",
    "type": "door",
}

bedroom_1 = {
    "name": "bedroom 1",
    "type": "room",
}

double_bed = {
    "name": "double bed",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

door_d = {
    "name": "door d",
    "type": "door",
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

bedroom_2 = {
    "name": "bedroom 2",
    "type": "room",
}

dining_table = {
    "name": "dining table",
    "type": "furniture",
}

living_room = {
    "name": "living room",
    "type": "room",
}

outside = {
    "name": "outside"
}

box = {
    "name": "box",
    "type": "safe"
}

door_e = {
    "name": "door e",
    "type": "door"
}

key_e = {
    "name": "key for door e",
    "type": "key",
    "target": door_e,
}

lucky_room = {
    "name": "lucky room"
}

all_rooms = [game_room, bedroom_1, bedroom_2, living_room, lucky_room, outside]

all_doors = [door_a, door_b, door_c, door_d, door_e]

# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "door a": [game_room, bedroom_1],
    "bedroom 1": [queen_bed, door_a, door_b, door_c],
    "queen bed": [key_b],
    "door b": [bedroom_1, bedroom_2],
    "bedroom 2": [double_bed, dresser, door_b],
    "double bed": [key_c],
    "dresser": [key_d],
    "door c": [bedroom_1, living_room],
    "living room": [dining_table, door_c, door_d],
    "door d": [living_room, lucky_room],
    
    "box": [key_e],
    "door e": [lucky_room, outside],
    "lucky room": [box, door_d, door_e],
    "outside": [door_e],
}

# define game state. Do not directly change this dict.
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
# %load_ext autoreload
# %autoreload 2 
from functions import start_game

def main():
    game_state = INIT_GAME_STATE.copy()
    start_game(game_state, object_relations)

if __name__ == "__main__":
    main()
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in game room
# You explore the room. This is game room. You find couch, piano, door a
# You are now in game room
# You examine piano. You find key for door a.
# You are now in game room
# You examine door a. You unlock it with a key you have.
#
# You are now in bedroom 1
# You examine queen bed. You find key for door b.
# You are now in bedroom 1
# Not sure what you mean. Type 'explore' or 'examine'.
# You are now in bedroom 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       6     start_game(game_state, object_relations)
#       8 if __name__ == "__main__":
# ----> 9     main()
# ...
